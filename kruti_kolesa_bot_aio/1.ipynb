# %%
import pandas as pd
df = pd.read_excel("spares2.xlsx",names=["work","spare"])
df
# Out:
#                                                   work  \
# 0    Естественный износ заднего фонаря (выход из ст...
# 1    Естественный износ заднего фонаря (выход из ст...
# 2    Естественный износ передней фары (выход из стр...
# 3    Естественный износ передней фары (выход из стр...
# 4    Естественный износ передней фары (выход из стр...
# ..                                                 ...
# 516                Повреждение крыла (заднее/переднее)
# 517                Повреждение крыла (заднее/переднее)
# 518                Повреждение крыла (заднее/переднее)
# 519                Повреждение крыла (заднее/переднее)
# 520                Повреждение крыла (заднее/переднее)
#
#                                                  spare
# 0        Фонарь задний с поворотниками для Monster PRO
# 1    Фонарь задний с поворотниками для электровелос...
# 2                         Фара передняя Mingto Monster
# 3                            Фара передняя Monster PRO
# ...

# %%
df_works = pd.read_excel("works_norm.xlsx",names=['0','1','2','3','4'])
df.work.unique()
a = set(df_works['0'])-set(df.work.unique())
print(*list(a),sep="\n")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df_works = pd.read_excel("works_norm.xlsx",names=['0','1','2','3','4'])
#       2 df.work.unique()
#       3 a = set(df_works['0'])-set(df.work.unique())
#
# NameError: name 'pd' is not defined

# %%
df.work.unique()
# Out:
# array(['Естественный износ заднего фонаря (выход из строя светодиодов) электро',
#        'Естественный износ передней фары (выход из строя светодиодов) электро',
#        'Повреждение заднего фонаря', 'Повреждение передней фары',
#        'Повреждение поворотника PRO (1 штука)',
#        'Восстановление модулей управления велосипедом (РГ, МС, контр и тд)',
#        'Естественный износ контроллера электро',
#        'Естественный износ модуля света электро',
#        'Замена датчика холла естественный износ электро',
#        'Замена подшипников/сальников МК (естественный износ) электро',
#        'Замена подшипников/сальников переднего колеса (естественный износ) электро',
#        'Замена статора МК естественный износ электро',
#        'Перепайка диодов в фонаре электро', 'Ремонт проводки (пайка)',
#        'Установка модуля iot1', 'Установка модуля iot2',
#        'Внеочередная замена подшипников и сальников МК при нарушении сроков ТО',
# ...

# %%
df = pd.read_excel("works_norm.xlsx",names = ['work','time','type','sale','group'])
df_spares = pd.read_excel("spares2.xlsx",names = ['work','spare'])

df = pd.merge(df_spares,df,on='work')

df.
# Out:
#   Cell In[5], line 6
#     df.
#        ^
# SyntaxError: invalid syntax

# %%
df
# Out:
#                                                   work  \
# 0    Естественный износ заднего фонаря (выход из ст...
# 1    Естественный износ заднего фонаря (выход из ст...
# 2    Естественный износ передней фары (выход из стр...
# 3    Естественный износ передней фары (выход из стр...
# 4    Естественный износ передней фары (выход из стр...
# ..                                                 ...
# 516                Повреждение крыла (заднее/переднее)
# 517                Повреждение крыла (заднее/переднее)
# 518                Повреждение крыла (заднее/переднее)
# 519                Повреждение крыла (заднее/переднее)
# 520                Повреждение крыла (заднее/переднее)
#
#                                                  spare
# 0        Фонарь задний с поворотниками для Monster PRO
# 1    Фонарь задний с поворотниками для электровелос...
# 2                         Фара передняя Mingto Monster
# 3                            Фара передняя Monster PRO
# ...

# %%
with open('input.txt',encoding='utf8') as file:
 a = [i.rstrip() for i in file.readlines()]
a = [i for i in a if not ' (к)' in i]
a = [i for i in a if not ' (т)' in i ]
a = [i for i in a if not ' (кзх)' in i ]
a = [i for i in a if not ' (каз)' in i ]
a = [i for i in a if not ' (кзх)' in i ]
a = [i for i in a if not ' ВВ' in i]
a = list(set(a))

# %%
electro = [i for i in a if not  i.endswith('(м)')]

electro
# Out:
# ['Естественный износ кассеты/трещотки',
#  'Ремонт филиала',
#  'Утеря колодки',
#  'Прокачка гидравлического тормоза (1 шланг)',
#  'Повреждение BMS платы АКБ (замыкание гнезда зарядки)',
#  'замена колпака МК',
#  'Замена крыла зад/перед',
#  'Замена тормозного диска заднего (естественный износ) электро',
#  'ремонт тормозной системы',
#  'Повреждение тормозного барабана',
#  'Диагностика ручки газа',
#  'Повреждение звукового сигнала',
#  'Повреждение шланга гидравлического тормоза',
#  'замена седла',
#  'Естественный износ контроллера электро',
#  'Повреждение/механический разрыв цепи не в замке',
#  'Порча колодок (масляный налет)/физическое отсутствие',
#  'Замена тормозных колодок (естественный износ)',
#  'Повреждение заднего фонаря',
#  'Повреждение металлического корпуса АКБ (отверстия,нарушение геометрии)',
#  'Замена датчика тормоза',
#  'Выемка подседельного штыря (высверливание и т.д)',
#  'Повреждение кейса/крышки контроллера',
#  'замена сигнала',
# ...

# %%
mechanical = [i for i in a if i.endswith('(м)')]
mechanical
# Out:
# ['Повреждение тормозного механизма (м)',
#  'Повреждение ротора дискового тормоза/отсутствие болтов на роторе (м)',
#  'Повреждение системы шатунов (м)',
#  'Повреждение крыла (одна деталь)(м)',
#  'Повреждения защиты цепи (м)',
#  'Повреждение переключателя скоростей (перед/зад) (м)',
#  'Повреждение Каретки (м)',
#  'Повреждение обода/втулки заднего колеса (м)',
#  'Преднамеренный срыв брендированных наклеек/пломб. (м)',
#  'Повреждение выноса руля (м)',
#  'Повреждение обода/втулки переднего колеса (м)',
#  'Повреждение оси (перед/зад) (м)',
#  'Повреждение трещотки (м)',
#  'Повреждение педалей (м)',
#  'Повреждение подножки (м)',
#  'Повреждение руля (м)',
#  'Повреждение моноблока шифтерручка тормоза (м)',
#  'Повреждения, не поддающиеся ремонту (гибель Имущества) (м)',
#  'Повреждение хомута подседельного штыря (м)',
#  'Повреждение/механический разрыв цепи не в замке (м)',
#  'Повреждение/отсутствие подседельного штыря (м)',
# ...

# %%
import pandas
df = pandas.read_excel('works_norm.xlsx',)
# Out:
#               0.5
# count  166.000000
# mean     0.522289
# std      0.481711
# min      0.100000
# 25%      0.300000
# 50%      0.400000
# 75%      0.575000
# max      4.000000

# %%
import pandas as pd
df = pd.read_excel('df.xlsx',names = ['1','2','3','4','5','6','7'])
df
# Out:
#          1                                                  2  \
# 0      0.0  Естественный износ передней фары (выход из стр...
# 1      1.0  Естественный износ передней фары (выход из стр...
# 2      2.0  Естественный износ передней фары (выход из стр...
# 3      3.0                         Повреждение заднего фонаря
# 4      4.0                         Повреждение заднего фонаря
# ..     ...                                                ...
# 492  514.0                Повреждение крыла (заднее/переднее)
# 493  515.0                Повреждение крыла (заднее/переднее)
# 494  516.0                Повреждение крыла (заднее/переднее)
# 495  517.0                Повреждение крыла (заднее/переднее)
# 496    NaN                Повреждение крыла (заднее/переднее)
#
#                                                      3    4        5  \
# 0                         Фара передняя Mingto Monster  0.3  Электро
# 1                            Фара передняя Monster PRO  0.3  Электро
# ...

# %%
df[df[5]=='АКБ']
# Out:
#          1                                                  2  \
# 406  428.0                Бесплатная замена БМС платы электро
# 407  429.0                Бесплатная замена БМС платы электро
# 408  430.0                Бесплатная замена БМС платы электро
# 409  431.0                Бесплатная замена БМС платы электро
# 410  432.0  Естественный износ Гнезда ЗУ/разъема питания А...
# 411  433.0  Естественный износ Гнезда ЗУ/разъема питания А...
# 412  434.0  Естественный износ Гнезда ЗУ/разъема питания А...
# 413  435.0  Естественный износ Гнезда ЗУ/разъема питания А...
# 414  436.0  Естественный износ Гнезда ЗУ/разъема питания А...
# 415  437.0  Естественный износ Гнезда ЗУ/разъема питания А...
# 416  438.0  Естественный износ Гнезда ЗУ/разъема питания А...
# 417  439.0  Естественный износ Гнезда ЗУ/разъема питания А...
# 418  440.0    Замена замка зажигания в АКБ (выгорает контакт)
# 419  441.0  Повреждение гнезда зарядного устройства/разъем...
# ...
